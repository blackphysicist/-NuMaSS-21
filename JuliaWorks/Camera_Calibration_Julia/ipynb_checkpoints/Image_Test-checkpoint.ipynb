# %%
using ImageFeatures, Images, FileIO
img1 = load("images/images/image01.jpg")
img2 = load("images/images/image02.jpg")
[img1 img2]
# Out:
# 712×2144 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(0.514,0.376,0.251)  …  RGB{N0f8}(0.859,0.843,0.839)
#  RGB{N0f8}(0.514,0.376,0.251)     RGB{N0f8}(0.859,0.843,0.839)
#  RGB{N0f8}(0.514,0.376,0.251)     RGB{N0f8}(0.859,0.843,0.839)
#  RGB{N0f8}(0.514,0.376,0.251)     RGB{N0f8}(0.863,0.847,0.843)
#  RGB{N0f8}(0.514,0.376,0.251)     RGB{N0f8}(0.863,0.847,0.843)
#  RGB{N0f8}(0.514,0.376,0.251)  …  RGB{N0f8}(0.867,0.851,0.847)
#  RGB{N0f8}(0.514,0.376,0.251)     RGB{N0f8}(0.867,0.851,0.847)
#  RGB{N0f8}(0.514,0.376,0.251)     RGB{N0f8}(0.867,0.851,0.847)
#  RGB{N0f8}(0.51,0.373,0.247)      RGB{N0f8}(0.867,0.851,0.847)
#  RGB{N0f8}(0.51,0.373,0.247)      RGB{N0f8}(0.867,0.851,0.847)
#  RGB{N0f8}(0.51,0.373,0.247)   …  RGB{N0f8}(0.867,0.851,0.847)
#  RGB{N0f8}(0.51,0.373,0.247)      RGB{N0f8}(0.867,0.851,0.847)
#  RGB{N0f8}(0.51,0.373,0.247)      RGB{N0f8}(0.867,0.851,0.847)
#  ⋮                             ⋱
# ...

# %%
size(img1)
# Out:
# (712, 1072)

# %%
# To find feature points
features_1 = imcorner(img1, method=harris);

# %%
summary(features_1)
# Out:
# "712×1072 Array{Bool,2}"

# %%
using Plots, Interact, JLD, Images
gr(
    label="",
    markersize=5,
    markerstrokewidth=0.3,
    markerstrokecolor="white"
)
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-340411608160103242\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-6604566663850123427\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n     
# ...
